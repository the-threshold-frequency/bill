# %%
import requests
import json


dat = None
receiptOcrEndpoint = 'https://ocr.asprise.com/api/v1/receipt' # Receipt OCR API endpoint
imageFile = "bill2.jpg" # // Modify this to use your own file if necessary
r = requests.post(receiptOcrEndpoint, data = { \
  'client_id': 'TEST',        # Use 'TEST' for testing purpose \
  'recognizer': 'auto',       # can be 'US', 'CA', 'JP', 'SG' or 'auto' \
  'ref_no': 'ocr_python_123', # optional caller provided ref code \
  }, \
  files = {"file": open(imageFile, "rb")})

if r.status_code==200:
    print(r)
    print(r.text) # result in JSON

# Open a file for writing
with open('output2.json', 'w') as f:
    # Write Python output to JSON file
    data = json.loads(r.text)
    json.dump(data,f)

with open('output2.json', 'r') as f:
    dat = json.load(f)
    print(dat)
    print(type(dat))

for i in dat.keys():
    print(i)
# Out:
# <Response [200]>
# {
#   "ocr_type" : "receipts",
#   "request_id" : "P_223.178.82.108_lguyc493_sfs",
#   "ref_no" : "ocr_python_123",
#   "file_name" : "bill2.jpg",
#   "request_received_on" : 1682347620999,
#   "success" : true,
#   "image_width" : 2448,
#   "image_height" : 3264,
#   "image_rotation" : -0.011,
#   "recognition_completed_on" : 1682347622167,
#   "receipts" : [ {
#     "merchant_name" : "McDonald's",
#     "merchant_address" : "600 Lorong 4 Toa Payoh, #01-02, 600@Toa Payoh, Singapore 319515",
#     "merchant_phone" : "+65 6259 6362",
#     "merchant_website" : null,
#     "merchant_tax_reg_no" : "M2-0023981-4",
#     "merchant_company_reg_no" : null,
#     "region" : null,
#     "mall" : "600 @ Toa Payoh",
#     "country" : "SG",
#     "receipt_no" : "002201330026",
#     "date" : null,
#     "time" : null,
#     "items" : [ {
#       "amount" : 2.95,
#       "category" : null,
#       "description" : "Med Ice Lemon Tea",
#       "flags" : "",
#       "qty" : 1,
#       "remarks" : null,
#       "tags" : null,
#       "unitPrice" : null
#     }, {
#       "amount" : 2.40,
#       "category" : null,
#       "description" : "Coffee with Milk",
#       "flags" : "",
#       "qty" : 1,
#       "remarks" : null,
#       "tags" : null,
#       "unitPrice" : null
#     } ],
#     "currency" : "SGD",
#     "total" : 5.35,
#     "subtotal" : null,
#     "tax" : 0.35,
#     "service_charge" : null,
#     "tip" : null,
#     "payment_method" : "cash",
#     "payment_details" : null,
#     "credit_card_type" : null,
#     "credit_card_number" : null,
#     "ocr_text" : "         McDonald's Toa Payoh Central\n           ยน600 @ Toa Payoh #01-02,\n               Singapore 319515\n                Tel: 62596362\n       McDonald's Restaurants Pte Ltd\n          GST REGN NO: M2-0023981-4\n                 TAX INVOICE\n   INV# 002201330026\n  ORD #57 -REG #1-13/01/2016 15:49:52\n  QTY ITEM                            TOTAL\n    1 Med Ice Lemon Tea                2.95\n    1 Coffee with Milk                 2.40\n Eat-In Total (incl GST)               5.35\n Cash Tendered                        10.00\n Change                                4.65\n TOTAL INCLUDES GST OF                  0.35\n     Thank You and Have A Nice Day",
#     "ocr_confidence" : 97.74,
#     "width" : 1957,
#     "height" : 2384,
#     "avg_char_width" : 45.768,
#     "avg_line_height" : 79.3626,
#     "category" : "meals/restaurant",
#     "source_locations" : {
#       "total" : [ [ {
#         "x" : 1906,
#         "y" : 1962
#       }, {
#         "x" : 2134,
#         "y" : 1967
#       }, {
#         "x" : 2132,
#         "y" : 2058
#       }, {
#         "x" : 1904,
#         "y" : 2052
#       } ] ],
#       "receipt_no" : [ [ {
#         "x" : 498,
#         "y" : 1228
#       }, {
#         "x" : 1082,
#         "y" : 1224
#       }, {
#         "x" : 1082,
#         "y" : 1300
#       }, {
#         "x" : 499,
#         "y" : 1304
#       } ] ],
#       "doc" : [ [ {
#         "x" : 74,
#         "y" : 344
#       }, {
#         "x" : 2227,
#         "y" : 320
#       }, {
#         "x" : 2256,
#         "y" : 2943
#       }, {
#         "x" : 103,
#         "y" : 2967
#       } ] ],
#       "tax" : [ [ {
#         "x" : 1933,
#         "y" : 2466
#       }, {
#         "x" : 2157,
#         "y" : 2461
#       }, {
#         "x" : 2159,
#         "y" : 2557
#       }, {
#         "x" : 1935,
#         "y" : 2562
#       } ] ],
#       "merchant_phone" : [ [ {
#         "x" : 1095,
#         "y" : 732
#       }, {
#         "x" : 1477,
#         "y" : 732
#       }, {
#         "x" : 1477,
#         "y" : 808
#       }, {
#         "x" : 1095,
#         "y" : 808
#       } ] ],
#       "merchant_tax_reg_no" : [ [ {
#         "x" : 1171,
#         "y" : 918
#       }, {
#         "x" : 1748,
#         "y" : 910
#       }, {
#         "x" : 1749,
#         "y" : 990
#       }, {
#         "x" : 1173,
#         "y" : 999
#       } ] ]
#     }
#   } ]
# }
# {'ocr_type': 'receipts', 'request_id': 'P_223.178.82.108_lguyc493_sfs', 'ref_no': 'ocr_python_123', 'file_name': 'bill2.jpg', 'request_received_on': 1682347620999, 'success': True, 'image_width': 2448, 'image_height': 3264, 'image_rotation': -0.011, 'recognition_completed_on': 1682347622167, 'receipts': [{'merchant_name': "McDonald's", 'merchant_address': '600 Lorong 4 Toa Payoh, #01-02, 600@Toa Payoh, Singapore 319515', 'merchant_phone': '+65 6259 6362', 'merchant_website': None, 'merchant_tax_reg_no': 'M2-0023981-4', 'merchant_company_reg_no': None, 'region': None, 'mall': '600 @ Toa Payoh', 'country': 'SG', 'receipt_no': '002201330026', 'date': None, 'time': None, 'items': [{'amount': 2.95, 'category': None, 'description': 'Med Ice Lemon Tea', 'flags': '', 'qty': 1, 'remarks': None, 'tags': None, 'unitPrice': None}, {'amount': 2.4, 'category': None, 'description': 'Coffee with Milk', 'flags': '', 'qty': 1, 'remarks': None, 'tags': None, 'unitPrice': None}], 'currency': 'SGD', 'total': 5.35, 'subtotal': None, 'tax': 0.35, 'service_charge': None, 'tip': None, 'payment_method': 'cash', 'payment_details': None, 'credit_card_type': None, 'credit_card_number': None, 'ocr_text': "         McDonald's Toa Payoh Central\n           ยน600 @ Toa Payoh #01-02,\n               Singapore 319515\n                Tel: 62596362\n       McDonald's Restaurants Pte Ltd\n          GST REGN NO: M2-0023981-4\n                 TAX INVOICE\n   INV# 002201330026\n  ORD #57 -REG #1-13/01/2016 15:49:52\n  QTY ITEM                            TOTAL\n    1 Med Ice Lemon Tea                2.95\n    1 Coffee with Milk                 2.40\n Eat-In Total (incl GST)               5.35\n Cash Tendered                        10.00\n Change                                4.65\n TOTAL INCLUDES GST OF                  0.35\n     Thank You and Have A Nice Day", 'ocr_confidence': 97.74, 'width': 1957, 'height': 2384, 'avg_char_width': 45.768, 'avg_line_height': 79.3626, 'category': 'meals/restaurant', 'source_locations': {'total': [[{'x': 1906, 'y': 1962}, {'x': 2134, 'y': 1967}, {'x': 2132, 'y': 2058}, {'x': 1904, 'y': 2052}]], 'receipt_no': [[{'x': 498, 'y': 1228}, {'x': 1082, 'y': 1224}, {'x': 1082, 'y': 1300}, {'x': 499, 'y': 1304}]], 'doc': [[{'x': 74, 'y': 344}, {'x': 2227, 'y': 320}, {'x': 2256, 'y': 2943}, {'x': 103, 'y': 2967}]], 'tax': [[{'x': 1933, 'y': 2466}, {'x': 2157, 'y': 2461}, {'x': 2159, 'y': 2557}, {'x': 1935, 'y': 2562}]], 'merchant_phone': [[{'x': 1095, 'y': 732}, {'x': 1477, 'y': 732}, {'x': 1477, 'y': 808}, {'x': 1095, 'y': 808}]], 'merchant_tax_reg_no': [[{'x': 1171, 'y': 918}, {'x': 1748, 'y': 910}, {'x': 1749, 'y': 990}, {'x': 1173, 'y': 999}]]}}]}
# <class 'dict'>
# ocr_type
# request_id
# ref_no
# file_name
# request_received_on
# success
# image_width
# image_height
# image_rotation
# recognition_completed_on
# receipts

# %%
from flask import Flask,request
from flask import render_template
import sqlite3

# create the table if it doesn't exist


app = Flask(_name_)
@app.route('/')
def hello_world():
    return render_template('main.html',init_dict={"Title":"Pharmacy Management System"})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# e:\mpp\htdocs\bill\bill.ipynb Cell 3 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/mpp/htdocs/bill/bill.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from flask import Flask,request
#       <a href='vscode-notebook-cell:/e%3A/mpp/htdocs/bill/bill.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from flask import render_template
#       <a href='vscode-notebook-cell:/e%3A/mpp/htdocs/bill/bill.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import sqlite3
#
# ModuleNotFoundError: No module named 'flask'
